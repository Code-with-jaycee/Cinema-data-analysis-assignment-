# %% [markdown]
# # Step 1
# Importing all necessary imports

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 2
# Reading data as dataframe

# %%
data = pd.read_csv("cinema.csv")
data.head(2)
# Out:
#    Unnamed: 0       Title  title_year     budget      Gross      actor_1_name  \
# 0           0  La La Land        2016   30000000  151101803      Ryan Gosling
# 1           1    Zootopia        2016  150000000  341268248  Ginnifer Goodwin
#
#     actor_2_name actor_3_name  actor_1_facebook_likes  actor_2_facebook_likes  \
# 0     Emma Stone   Amiée Conn                   14000                 19000.0
# 1  Jason Bateman   Idris Elba                    2800                 28000.0
#
#    actor_3_facebook_likes  IMDb_rating    genre_1    genre_2 genre_3  Runtime  \
# 0                     NaN          8.2     Comedy      Drama   Music      128
# 1                 27000.0          8.1  Animation  Adventure  Comedy      108
#
#   content_rating Country
# 0          PG-13     USA
# 1             PG     USA

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'title_year', 'budget', 'Gross', 'actor_1_name',
#        'actor_2_name', 'actor_3_name', 'actor_1_facebook_likes',
#        'actor_2_facebook_likes', 'actor_3_facebook_likes', 'IMDb_rating',
#        'genre_1', 'genre_2', 'genre_3', 'Runtime', 'content_rating',
#        'Country'],
#       dtype='object')

# %%
data.corr()
# Out:
#                         Unnamed: 0  title_year    budget     Gross  \
# Unnamed: 0                1.000000   -0.265008 -0.682457 -0.423238
# title_year               -0.265008    1.000000  0.047194  0.108930
# budget                   -0.682457    0.047194  1.000000  0.760114
# Gross                    -0.423238    0.108930  0.760114  1.000000
# actor_1_facebook_likes   -0.255931    0.004138  0.123067  0.070104
# actor_2_facebook_likes   -0.403100    0.274125  0.051393  0.060883
# actor_3_facebook_likes   -0.413985    0.191715  0.328815  0.294711
# IMDb_rating              -0.185250    0.140239  0.225800  0.270453
# Runtime                  -0.259044    0.031092  0.352666  0.255991
#
#                         actor_1_facebook_likes  actor_2_facebook_likes  \
# Unnamed: 0                           -0.255931               -0.403100
# title_year                            0.004138                0.274125
# budget                                0.123067                0.051393
# ...

# %%
Gross_budget = data[["Gross", "budget"]]
plt.bar(Gross_budget)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Projects\Cinema-data-analysis-assignment-\main.ipynb Cell 7 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Projects/Cinema-data-analysis-assignment-/main.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> Gross_budget = data[["Gross", "budget"]]
# ----> <a href='vscode-notebook-cell:/d%3A/Projects/Cinema-data-analysis-assignment-/main.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> plt.bar(Gross_budget)
#
# TypeError: bar() missing 1 required positional argument: 'height'
