# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Read data into Python Pandas as a Dataframe

# %%
cinema_data = pd.read_csv("cinema.csv")
# cinema_data = pd.DataFrame(cinema_data)
cinema_data.head()
# Out:
#    Unnamed: 0                  Title  title_year     budget      Gross  \
# 0           0             La La Land        2016   30000000  151101803
# 1           1               Zootopia        2016  150000000  341268248
# 2           2                   Lion        2016   12000000   51738905
# 3           3                Arrival        2016   47000000  100546139
# 4           4  Manchester by the Sea        2016    9000000   47695371
#
#        actor_1_name        actor_2_name     actor_3_name  \
# 0      Ryan Gosling          Emma Stone       Amiée Conn
# 1  Ginnifer Goodwin       Jason Bateman       Idris Elba
# 2         Dev Patel       Nicole Kidman      Rooney Mara
# 3         Amy Adams       Jeremy Renner  Forest Whitaker
# 4     Casey Affleck  Michelle Williams     Kyle Chandler
#
#    actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 0                   14000                 19000.0                     NaN
# ...

# %% [markdown]
# b. Check column information for the data

# %%
cinema_data.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'title_year', 'budget', 'Gross', 'actor_1_name',
#        'actor_2_name', 'actor_3_name', 'actor_1_facebook_likes',
#        'actor_2_facebook_likes', 'actor_3_facebook_likes', 'IMDb_rating',
#        'genre_1', 'genre_2', 'genre_3', 'Runtime', 'content_rating',
#        'Country'],
#       dtype='object')

# %%
cinema_data.describe()
# Out:
#        Unnamed: 0   title_year        budget         Gross  \
# count  100.000000   100.000000  1.000000e+02  1.000000e+02
# mean    49.500000  2012.820000  7.838400e+07  1.468679e+08
# std     29.011492     1.919491  7.445295e+07  1.454004e+08
# min      0.000000  2010.000000  3.000000e+06  2.238380e+05
# 25%     24.750000  2011.000000  1.575000e+07  4.199752e+07
# 50%     49.500000  2013.000000  4.225000e+07  1.070266e+08
# 75%     74.250000  2014.000000  1.500000e+08  2.107548e+08
# max     99.000000  2016.000000  2.600000e+08  9.366622e+08
#
#        actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# count              100.000000               99.000000               98.000000
# mean             13407.270000             7377.303030             3002.153061
# std              10649.037862            13471.568216             6940.301133
# min                 39.000000               12.000000                0.000000
# ...

# %% [markdown]
# c. Convert the unit of the budget and gross columns from $ to million $ first by
# dividing by 1,000,000.

# %%
# cinema_data['budget']
cinema_data["budget"] = cinema_data["budget"] / 1000000
# cinema_data['budget']


cinema_data["Gross"] = cinema_data["Gross"] / 1000000

# %%
cinema_data
# Out:
#     Unnamed: 0                                         Title  title_year  \
# 0            0                                    La La Land        2016
# 1            1                                      Zootopia        2016
# 2            2                                          Lion        2016
# 3            3                                       Arrival        2016
# 4            4                         Manchester by the Sea        2016
# ..         ...                                           ...         ...
# 95          95                                      Whiplash        2014
# 96          96                               Before Midnight        2013
# 97          97    Star Wars: Episode VII - The Force Awakens        2015
# 98          98  Harry Potter and the Deathly Hallows: Part I        2010
# 99          99                       Tucker and Dale vs Evil        2010
#
#       budget       Gross              actor_1_name        actor_2_name  \
# ...

# %% [markdown]
# Rename the budget and gross columns to budget(Million $) and
# gross(Million $).

# %%
cinema_data = cinema_data.rename(columns={"budget": "budget (Millions $)", "Gross": "gross (Millions $)"})
# cinema_data_1
cinema_data
# Out:
#     Unnamed: 0                                         Title  title_year  \
# 0            0                                    La La Land        2016
# 1            1                                      Zootopia        2016
# 2            2                                          Lion        2016
# 3            3                                       Arrival        2016
# 4            4                         Manchester by the Sea        2016
# ..         ...                                           ...         ...
# 95          95                                      Whiplash        2014
# 96          96                               Before Midnight        2013
# 97          97    Star Wars: Episode VII - The Force Awakens        2015
# 98          98  Harry Potter and the Deathly Hallows: Part I        2010
# 99          99                       Tucker and Dale vs Evil        2010
#
#     budget (Millions $)  gross (Millions $)              actor_1_name  \
# ...

# %% [markdown]
# e. Create a new column called profit which contains the difference of the two columns:
# gross(Million $) and budget(Million $).

# %%
cinema_data.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'title_year', 'budget (Millions $)',
#        'gross (Millions $)', 'actor_1_name', 'actor_2_name', 'actor_3_name',
#        'actor_1_facebook_likes', 'actor_2_facebook_likes',
#        'actor_3_facebook_likes', 'IMDb_rating', 'genre_1', 'genre_2',
#        'genre_3', 'Runtime', 'content_rating', 'Country'],
#       dtype='object')

# %%
cinema_data["profit"] =  cinema_data["gross (Millions $)"] - cinema_data["budget (Millions $)"] 
cinema_data.head()
# Out:
#    Unnamed: 0                  Title  title_year  budget (Millions $)  \
# 0           0             La La Land        2016             0.000030
# 1           1               Zootopia        2016             0.000150
# 2           2                   Lion        2016             0.000012
# 3           3                Arrival        2016             0.000047
# 4           4  Manchester by the Sea        2016             0.000009
#
#    gross (Millions $)      actor_1_name        actor_2_name     actor_3_name  \
# 0          151.101803      Ryan Gosling          Emma Stone       Amiée Conn
# 1          341.268248  Ginnifer Goodwin       Jason Bateman       Idris Elba
# 2           51.738905         Dev Patel       Nicole Kidman      Rooney Mara
# 3          100.546139         Amy Adams       Jeremy Renner  Forest Whitaker
# 4           47.695371     Casey Affleck  Michelle Williams     Kyle Chandler
#
#    actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# ...

# %% [markdown]
# f. Sort the data-frame using the profit column as reference.

# %%
cinema_data = cinema_data.sort_values("profit")
cinema_data.head()
# Out:
#     Unnamed: 0                    Title  title_year  budget (Millions $)  \
# 99          99  Tucker and Dale vs Evil        2010             0.000005
# 89          89                    Amour        2012             0.000009
# 39          39        The Little Prince        2015             0.000081
# 82          82                  Flipped        2010             0.000014
# 96          96          Before Midnight        2013             0.000003
#
#     gross (Millions $)              actor_1_name       actor_2_name  \
# 99            0.223838            Katrina Bowden       Tyler Labine
# 89            0.225377          Isabelle Huppert    Emmanuelle Riva
# 39            1.339152              Jeff Bridges       James Franco
# 82            1.752214          Madeline Carroll  Rebecca De Mornay
# 96            8.114507  Seamus Davey-Fitzpatrick       Ariane Labed
#
#               actor_3_name  actor_1_facebook_likes  actor_2_facebook_likes  \
# ...

# %% [markdown]
# g. Extract the top ten profiting movies in descending order and store them in a new dataframe called top10.

# %%
top10 = cinema_data[:10].sort_values(
    by ="profit",
    
    ascending=False)

# %%
top10
# Out:
#     Unnamed: 0                            Title  title_year  \
# 84          84  The Perks of Being a Wallflower        2012
# 87          87                         Nebraska        2013
# 88          88                       About Time        2013
# 66          66                          Warrior        2011
# 95          95                         Whiplash        2014
# 96          96                  Before Midnight        2013
# 82          82                          Flipped        2010
# 39          39                The Little Prince        2015
# 89          89                            Amour        2012
# 99          99          Tucker and Dale vs Evil        2010
#
#     budget (Millions $)  gross (Millions $)              actor_1_name  \
# 84             0.000013           17.738570              Logan Lerman
# 87             0.000012           17.613460              Devin Ratray
# 88             0.000012           15.294553                Tom Hughes
# ...

# %%
cinema_data['Unnamed: 0'].head()
# Out:
# 99    99
# 89    89
# 39    39
# 82    82
# 96    96
# Name: Unnamed: 0, dtype: int64

# %% [markdown]
# h. Plot a scatter or a joint plot between the columns budget and profit. Make any
# observations on the scatter graph.

# %%
cinema_data.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'title_year', 'budget (Millions $)',
#        'gross (Millions $)', 'actor_1_name', 'actor_2_name', 'actor_3_name',
#        'actor_1_facebook_likes', 'actor_2_facebook_likes',
#        'actor_3_facebook_likes', 'IMDb_rating', 'genre_1', 'genre_2',
#        'genre_3', 'Runtime', 'content_rating', 'Country', 'profit'],
#       dtype='object')

# %%
from matplotlib.pyplot import legend, sca, xlabel, ylabel


scatter_plot = plt.scatter(cinema_data["budget (Millions $)"] , cinema_data["profit"], c="red")

plt.show()

# %%
sns.jointplot(data=cinema_data, x = "budget (Millions $)", y = "profit", height=5)

# %% [markdown]
# Observation

# %% [markdown]
# The scatter plot is highly populated towards the left hand side of the graph this conclude that the lower the budget used is directly propotional to the amount of profit that will be received.
#
# The highest profit that was incured reached around 700 million. This also conclude that the higher the budget lead to high chances of recieving alot of profist.

# %% [markdown]
# Extract the movies with a negative profit and store them in a new data-frame called
# Neg_profit.

# %%
Neg_profit = cinema_data[cinema_data.profit < 0]
Neg_profit
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Title, title_year, budget (Millions $), gross (Millions $), actor_1_name, actor_2_name, actor_3_name, actor_1_facebook_likes, actor_2_facebook_likes, actor_3_facebook_likes, IMDb_rating, genre_1, genre_2, genre_3, Runtime, content_rating, Country, profit]
# Index: []

# %%
plt.bar(cinema_data['genre_1'], cinema_data['Unnamed: 0'])
# Out:
# <BarContainer object of 100 artists>

# %% [markdown]
# Plot a bar graph of genre_1 movies.

# %%
cinema_data.plot.bar(x ='genre_1')
# Out:
# <AxesSubplot:xlabel='genre_1'>
